# %%
import sys

# The installation is verified from the Command Prompt using:  python --version
print("Python version :", sys.version.split()[0])
print("Python is installed and added to PATH successfully.")
# Out:
# Python version : 3.11.15
# Python is installed and added to PATH successfully.

# %%
# Libraries are installed from the Command Prompt using pip:
#     pip install jupyter
#     pip install numpy pandas matplotlib seaborn

import importlib

for lib in ["numpy", "pandas", "matplotlib", "seaborn"]:
    status = "installed" if importlib.util.find_spec(lib) else "not found"
    print(f"{lib:12s} -> {status}")
# Out:
# numpy        -> installed
# pandas       -> installed
# matplotlib   -> installed
# seaborn      -> installed

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

print("NumPy      :", np.__version__)
print("Pandas     :", pd.__version__)
print("Matplotlib :", matplotlib.__version__)
print("Seaborn    :", sns.__version__)
# Out:
# NumPy      : 2.4.4
# Pandas     : 3.0.2
# Matplotlib : 3.10.9
# Seaborn    : 0.13.2

# %%
# A basic Python program executed inside a Code cell
name = "Data Analytics Lab"
values = [10, 20, 30, 40, 50]

print("Welcome to", name)
print("Values     :", values)
print("Sum        :", sum(values))
print("Average    :", sum(values) / len(values))

for i, v in enumerate(values, start=1):
    print(f"Item {i} = {v}")
# Out:
# Welcome to Data Analytics Lab
# Values     : [10, 20, 30, 40, 50]
# Sum        : 150
# Average    : 30.0
# Item 1 = 10
# Item 2 = 20
# Item 3 = 30
# Item 4 = 40
# Item 5 = 50

# %%
from IPython.display import Markdown, display

# A Markdown cell is created by changing the cell type to 'Markdown'
# and running it with Shift + Enter. The same rendering is shown below.
display(Markdown('''
# Experiment 1a
## Setting Up the Python Environment

**Objective:** configure Jupyter Notebook for data analytics.

- Python installed and added to PATH
- Jupyter Notebook installed
- Libraries: *NumPy*, *Pandas*, *Matplotlib*, *Seaborn*
'''))
# Out:
# # Experiment 1a
# ## Setting Up the Python Environment
#
# **Objective:** configure Jupyter Notebook for data analytics.
#
# - Python installed and added to PATH
# - Jupyter Notebook installed
# - Libraries: *NumPy*, *Pandas*, *Matplotlib*, *Seaborn*

# %%
# Loading the sales dataset into the notebook
df = pd.read_csv("sales_data.csv")

print("Shape of the dataset :", df.shape)
print("Column names         :", list(df.columns))
df.head()
# Out:
# Shape of the dataset : (30, 3)
# Column names         : ['Product', 'Region', 'Sales']
#    Product Region  Sales
# 0   Laptop  North  50000
# 1   Mobile  South  35000
# 2  Printer   East  25000
# 3   Laptop   West  45000
# 4   Mobile  North  40000

# %%
# %matplotlib inline

region_sales = df.groupby("Region")["Sales"].sum()

plt.figure(figsize=(6, 3.5))
plt.plot(region_sales.index, region_sales.values, marker="o")
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
